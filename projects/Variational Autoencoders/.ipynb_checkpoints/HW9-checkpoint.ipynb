# %% [markdown]
# # **Homework 9: Variational Autoencoders**

# %% [markdown]
# ## **About**
#
# ### **Due**
#
# Monday 4/22/19, 11:59 PM CST
#
# ### **Goal**
#
# This homework focuses on creating variational autoencoders applied to the MNIST dataset.

# %% [markdown]
# ## Dev Environment
# ### Working on Google Colab
# You may choose to work locally or on Google Colaboratory. You have access to free compute through this service.
# 1. Visit https://colab.research.google.com/drive
# 2. Navigate to the **`Upload`** tab, and upload your `HW10.ipynb`
# 3. Now on the top right corner, under the `Comment` and `Share` options, you should see a `Connect` option. Once you are connected, you will have access to a VM with 12GB RAM, 50 GB disk space and a single GPU. The dropdown menu will allow you to connect to a local runtime as well.
#
# **Notes:**
# * **If you do not have a working setup for Python 3, this is your best bet. It will also save you from heavy installations like `tensorflow` if you don't want to deal with those.**
# * ***There is a downside*. You can only use this instance for a single 12-hour stretch, after which your data will be deleted, and you would have redownload all your datasets, any libraries not already on the VM, and regenerate your logs**.
#
#
# ### Installing PyTorch and Dependencies
#
# The instructions for installing and setting up PyTorch can be found at https://pytorch.org/get-started/locally/. Make sure you follow the instructions for your machine. For any of the remaining libraries used in this assignment:
# * We have provided a `hw8_requirements.txt` file on the homework web page.
# * Download this file, and in the same directory you can run `pip3 install -r hw8_requirements.txt`
#
# Check that PyTorch installed correctly by running the following:

# %%
import torch
torch.rand(5, 3)
# Out:
# tensor([[0.6007, 0.9105, 0.8501],
#         [0.5959, 0.8738, 0.8560],
#         [0.8422, 0.8097, 0.5637],
#         [0.5652, 0.1923, 0.3424],
#         [0.5898, 0.1731, 0.2281]])

# %% [markdown]
# The output should look something like
#
# ```python
# tensor([[0.3380, 0.3845, 0.3217],
#         [0.8337, 0.9050, 0.2650],
#         [0.2979, 0.7141, 0.9069],
#         [0.1449, 0.1132, 0.1375],
#         [0.4675, 0.3947, 0.1426]])
# ```
#
# ### Let's get started with the assignment.

# %% [markdown]
# ## **Instructions**
#
# ### **Part 1 - Datasets and Dataloaders**
#
# This part of the assignment is similar to HW 8.
#
# **Create a directory named hw9_data with the following command.**

# %%
# !mkdir hw9_data

# %% [markdown]
# **Now use `torch.datasets.MNIST` to load the Train and Test data into `hw9_data`.**
# * ** Use the directory you created above as the `root` directory for your datasets**
# * ** Populate the `transformations` variable with any transformations you would like to perform on your data.** (Hint: You will need to do at least one)
# * **Pass your `transformations` variable to `torch.datasets.MNIST`. This allows you to perform arbitrary transformations to your data at loading time.**

# %%
from torchvision import datasets, transforms

root = 'hw9_data'
transformations = transforms.ToTensor()
mnist_train = datasets.MNIST(root, train=True, download=True, transform=transformations) 
mnist_test = datasets.MNIST(root, train=False, download=True, transform=transformations)

# %% [markdown]
# **Any file in our dataset will now be read at runtime, and the specified transformations we need on it will be applied when we need it.**.
#
# We could iterate through these directly using a loop, but this is not idiomatic. PyTorch provides us with this abstraction in the form of `DataLoaders`. The module of interest is `torch.utils.data.DataLoader`.
#
# `DataLoader` allows us to do lots of useful things
# * Group our data into batches
# * Shuffle our data
# * Load the data in parallel using `multiprocessing` workers
#
# **Use `DataLoader` to create a loader for the training set and one for the testing set**
# * **Use a `batch_size` of 32 to start, you may change it if you wish.**
# * **Set the `shuffle` parameter to `True`.**
#
# **Check that the data was loaded successfully before proceeding to the next sections. **

# %%
from torch.utils.data import DataLoader

BATCH_SIZE=32
kwargs = {'num_workers':1, 'pin_memory':True}
train_loader = DataLoader(mnist_train, batch_size=BATCH_SIZE, shuffle=True, **kwargs)
test_loader = DataLoader(mnist_test, batch_size=BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# ## **Part 2 - Encoder and Decoders (0 points)**
#
# In this section we will be creating the encoder and decoder for our variational autoencoder (VAE).
#
# You can take a look at the following to understand how VAE's work.
#
# *   https://towardsdatascience.com/intuitively-understanding-variational-autoencoders-1bfe67eb5daf
# *  http://kvfrans.com/variational-autoencoders-explained/
# *  https://jmetzen.github.io/2015-11-27/vae.html
#
# VAEs work around a latent space who's dimension can be chosen by us. We will leave this as a parameter for the Encoder and Decoder classes that you will have to populate.
#
# Feel free to use any network architecture that you wish. Try simpler network structures like a few linear layers before trying anything more complicated.
#
# ### For the Encoder:
#
# *   **Finish the __init__() function.**
# *  **Finish the forward() function.**
# *  **Assume that input to forward, x, is of shape (batch_size, 28,28)**
# *  **forward() should return two tensors of size latent_dim like a standard encoder of a VAE**
# * **One of the tensors should correspond to the mean of the encoding and the other tensor should correspond to the variance. In practice, it is easier to model the output as the log of the variance (logvar) and we will too**
#
# ### For the Decoder:
#
# *   **Finish the __init__() function.**
# *  **Finish the forward() function.**
# *  **Assume that input to forward, x, is of shape (batch_size, latent_dim)**
# *  **forward() should return a tensor of shape (batch_size, 28,28)**
# * **Make sure that the output lies in the same range as the input to the encoder (Hint: Sigmoid?)**

# %%
from torch import nn
from torch.nn import functional as F
inputPixel = 784
outputs = 400

class Encoder(nn.Module):
  def __init__(self, latent_dim):
    super(Encoder, self).__init__()
    self.fc1 = nn.Linear(inputPixel,outputs)
    self.relu = nn.ReLU()
    self.fc21 = nn.Linear(outputs, latent_dim)
    self.fc22 = nn.Linear(outputs, latent_dim)
  
  def forward(self, x):
    h1 = self.relu(self.fc1(x))
    return self.fc21(h1), self.fc22(h1)

class Decoder(nn.Module):
  def __init__(self, latent_dim):
    super(Decoder, self).__init__()
    self.relu = nn.ReLU()
    self.fc3 = nn.Linear(latent_dim, outputs)
    self.fc4 = nn.Linear(outputs, inputPixel)
    self.sigmoid = nn.Sigmoid()
    
  def forward(self,x):
    h3 = self.relu(self.fc3(x))
    return self.sigmoid(self.fc4(h3))

# %% [markdown]
# ## **Part 3: Training and loss functions** (0 points)
#
# Recall that the encoder outputs the mean (mu) and the log of the variance (logvar). This implies that the latent vector of the input image follows a gaussian distribution with mean (mu) and standard deviation (e^[0.5\*logvar]). To decode this information, the decoder needs a sample from this distribution.
#
# **Complete the sample function to generate these samples **

# %%
def sample(mu, logvar):
    std = logvar.mul(0.5).exp_()
    eps  =std.data.new(std.size()).normal_()
    return eps.mul(std).add_(mu)

# %% [markdown]
# We also need to create the loss function. Assume that x are your input images and x_hat are your reconstructions of these input images, complete the following loss for a VAE. (Hint: You will need to use mu and logvar as well)

# %%
def vae_loss(x, x_hat, mu, logvar):
    BCE = F.binary_cross_entropy(x, x_hat.view(-1, inputPixel))
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    KLD /= BATCH_SIZE * inputPixel
    return BCE + KLD

# %% [markdown]
# In the following we will instantiate an Encoder and Decoder with a latent dimension of 32.
#
# We also define a single optimizer that optimizes the parameters of both the Encoder and the Decoder together. Feel free to use any optimizer of your choice.

# %%
from torch import optim

encoder = Encoder(latent_dim = 32)
encoder.cuda()
decoder = Decoder(latent_dim = 32)
decoder.cuda()
params = list(encoder.parameters())+list(decoder.parameters())
optimizer = optim.Adam(params, lr=1e-3)

# %% [markdown]
# Complete the train function that takes input encoder, decoder, train_loader, optimizer, and number of epochs you wish to train your model for.
#
# Training will involve:
#
# 1.   **One epoch is defined as a full pass of your dataset through your model. We choose the number of epochs we wish to train our model for.**
# 2.   **For each batch, use the encoder to generate the mu and logvar.**
# 3. **Sample a latent vector for each image in the batch and feed this to the decoder to generate the decoded images.**
# 4. **Calculate the loss function for this batch.**
# 5. **Now calculate the gradients for each parameter you are optimizing over. (Hint: Your loss function object can do this for you)**
# 6. **Update your model parameters (Hint: The optimizer comes in here)**
# 7. ** Set the gradients in your model to zero for the next batch.**

# %%
import tensorflow as tf
def train(encoder, decoder, train_loader, optimizer, num_epochs = 10):
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.view(data.shape[0],-1)
        data = data.cuda()
        optimizer.zero_grad()
        mu, logvar = encoder.forward(data)
        z = sample(mu, logvar)
        recon_x = decoder.forward(z)
        loss = vae_loss(recon_x, data, mu, logvar)
        loss.backward()
        train_loss += loss
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                num_epochs, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss / len(data)))
        print('====> Epoch: {} Average loss: {:.4f}'.format(
              num_epochs, train_loss / len(train_loader.dataset)))

# %% [markdown]
# Finally call train with the relevant parameters.
#
# Note : This function may take a while to complete if you're training for many epochs on a cpu. This is where it comes in handy to be running on Google Colab, or just have a GPU on hand.

# %%
train(encoder, decoder, train_loader, optimizer, num_epochs = 10)
# Out:
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.006602
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# Train Epoch: 10 [320/60000 (1%)]	Loss: 0.006210
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0000
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# Train Epoch: 10 [640/60000 (1%)]	Loss: 0.006300
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# Train Epoch: 10 [960/60000 (2%)]	Loss: 0.006803
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# Train Epoch: 10 [1280/60000 (2%)]	Loss: 0.005911
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0001
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# Train Epoch: 10 [1600/60000 (3%)]	Loss: 0.005747
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# Train Epoch: 10 [1920/60000 (3%)]	Loss: 0.006118
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# Train Epoch: 10 [2240/60000 (4%)]	Loss: 0.006134
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0002
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# Train Epoch: 10 [2560/60000 (4%)]	Loss: 0.006205
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# Train Epoch: 10 [2880/60000 (5%)]	Loss: 0.006553
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# Train Epoch: 10 [3200/60000 (5%)]	Loss: 0.005991
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0003
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# Train Epoch: 10 [3520/60000 (6%)]	Loss: 0.005918
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# Train Epoch: 10 [3840/60000 (6%)]	Loss: 0.005616
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# Train Epoch: 10 [4160/60000 (7%)]	Loss: 0.005823
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0004
# Train Epoch: 10 [4480/60000 (7%)]	Loss: 0.005427
# ====> Epoch: 10 Average loss: 0.0004
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# Train Epoch: 10 [4800/60000 (8%)]	Loss: 0.005711
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# Train Epoch: 10 [5120/60000 (9%)]	Loss: 0.005723
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# Train Epoch: 10 [5440/60000 (9%)]	Loss: 0.005284
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0005
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# Train Epoch: 10 [5760/60000 (10%)]	Loss: 0.005523
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# Train Epoch: 10 [6080/60000 (10%)]	Loss: 0.005140
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# Train Epoch: 10 [6400/60000 (11%)]	Loss: 0.005885
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0006
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# Train Epoch: 10 [6720/60000 (11%)]	Loss: 0.006006
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# Train Epoch: 10 [7040/60000 (12%)]	Loss: 0.005749
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# Train Epoch: 10 [7360/60000 (12%)]	Loss: 0.005291
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0007
# Train Epoch: 10 [7680/60000 (13%)]	Loss: 0.005809
# ====> Epoch: 10 Average loss: 0.0007
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# Train Epoch: 10 [8000/60000 (13%)]	Loss: 0.005481
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# Train Epoch: 10 [8320/60000 (14%)]	Loss: 0.005267
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# Train Epoch: 10 [8640/60000 (14%)]	Loss: 0.005094
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0008
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# Train Epoch: 10 [8960/60000 (15%)]	Loss: 0.005167
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# Train Epoch: 10 [9280/60000 (15%)]	Loss: 0.005775
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# Train Epoch: 10 [9600/60000 (16%)]	Loss: 0.005488
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# ====> Epoch: 10 Average loss: 0.0009
# Train Epoch: 10 [9920/60000 (17%)]	Loss: 0.004960
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# Train Epoch: 10 [10240/60000 (17%)]	Loss: 0.005972
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# Train Epoch: 10 [10560/60000 (18%)]	Loss: 0.005580
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# Train Epoch: 10 [10880/60000 (18%)]	Loss: 0.004981
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0010
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# Train Epoch: 10 [11200/60000 (19%)]	Loss: 0.005601
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# Train Epoch: 10 [11520/60000 (19%)]	Loss: 0.005415
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# Train Epoch: 10 [11840/60000 (20%)]	Loss: 0.005415
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# ====> Epoch: 10 Average loss: 0.0011
# Train Epoch: 10 [12160/60000 (20%)]	Loss: 0.005578
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# Train Epoch: 10 [12480/60000 (21%)]	Loss: 0.004986
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.005300
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# Train Epoch: 10 [13120/60000 (22%)]	Loss: 0.005094
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0012
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# Train Epoch: 10 [13440/60000 (22%)]	Loss: 0.005560
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# Train Epoch: 10 [13760/60000 (23%)]	Loss: 0.005018
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# Train Epoch: 10 [14080/60000 (23%)]	Loss: 0.004906
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# Train Epoch: 10 [14400/60000 (24%)]	Loss: 0.005207
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0013
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# Train Epoch: 10 [14720/60000 (25%)]	Loss: 0.004999
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# Train Epoch: 10 [15040/60000 (25%)]	Loss: 0.004932
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# Train Epoch: 10 [15360/60000 (26%)]	Loss: 0.005338
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0014
# ====> Epoch: 10 Average loss: 0.0015
# Train Epoch: 10 [15680/60000 (26%)]	Loss: 0.004973
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# Train Epoch: 10 [16000/60000 (27%)]	Loss: 0.005044
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# Train Epoch: 10 [16320/60000 (27%)]	Loss: 0.005090
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# Train Epoch: 10 [16640/60000 (28%)]	Loss: 0.004728
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0015
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# Train Epoch: 10 [16960/60000 (28%)]	Loss: 0.004376
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# Train Epoch: 10 [17280/60000 (29%)]	Loss: 0.004889
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# Train Epoch: 10 [17600/60000 (29%)]	Loss: 0.005382
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# Train Epoch: 10 [17920/60000 (30%)]	Loss: 0.005179
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0016
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# Train Epoch: 10 [18240/60000 (30%)]	Loss: 0.005253
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# Train Epoch: 10 [18560/60000 (31%)]	Loss: 0.004818
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# Train Epoch: 10 [18880/60000 (31%)]	Loss: 0.004992
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0017
# ====> Epoch: 10 Average loss: 0.0018
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 0.005282
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# Train Epoch: 10 [19520/60000 (33%)]	Loss: 0.005345
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# Train Epoch: 10 [19840/60000 (33%)]	Loss: 0.004742
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# Train Epoch: 10 [20160/60000 (34%)]	Loss: 0.005280
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0018
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# Train Epoch: 10 [20480/60000 (34%)]	Loss: 0.005304
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# Train Epoch: 10 [20800/60000 (35%)]	Loss: 0.005385
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# Train Epoch: 10 [21120/60000 (35%)]	Loss: 0.004611
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# Train Epoch: 10 [21440/60000 (36%)]	Loss: 0.004963
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0019
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# Train Epoch: 10 [21760/60000 (36%)]	Loss: 0.005219
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# Train Epoch: 10 [22080/60000 (37%)]	Loss: 0.005111
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# Train Epoch: 10 [22400/60000 (37%)]	Loss: 0.005104
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# Train Epoch: 10 [22720/60000 (38%)]	Loss: 0.005166
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0020
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# Train Epoch: 10 [23040/60000 (38%)]	Loss: 0.004602
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# Train Epoch: 10 [23360/60000 (39%)]	Loss: 0.005222
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# Train Epoch: 10 [23680/60000 (39%)]	Loss: 0.004955
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# ====> Epoch: 10 Average loss: 0.0021
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.004595
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# Train Epoch: 10 [24320/60000 (41%)]	Loss: 0.004906
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# Train Epoch: 10 [24640/60000 (41%)]	Loss: 0.005046
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# Train Epoch: 10 [24960/60000 (42%)]	Loss: 0.004705
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0022
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# Train Epoch: 10 [25280/60000 (42%)]	Loss: 0.004983
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.004509
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# Train Epoch: 10 [25920/60000 (43%)]	Loss: 0.004651
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# Train Epoch: 10 [26240/60000 (44%)]	Loss: 0.004987
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0023
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# Train Epoch: 10 [26560/60000 (44%)]	Loss: 0.005025
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# Train Epoch: 10 [26880/60000 (45%)]	Loss: 0.004832
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# Train Epoch: 10 [27200/60000 (45%)]	Loss: 0.004735
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# Train Epoch: 10 [27520/60000 (46%)]	Loss: 0.004842
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0024
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# Train Epoch: 10 [27840/60000 (46%)]	Loss: 0.004683
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# Train Epoch: 10 [28160/60000 (47%)]	Loss: 0.004920
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# Train Epoch: 10 [28480/60000 (47%)]	Loss: 0.005020
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# Train Epoch: 10 [28800/60000 (48%)]	Loss: 0.005230
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0025
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# Train Epoch: 10 [29120/60000 (49%)]	Loss: 0.004879
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# Train Epoch: 10 [29440/60000 (49%)]	Loss: 0.004742
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# Train Epoch: 10 [29760/60000 (50%)]	Loss: 0.004820
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# Train Epoch: 10 [30080/60000 (50%)]	Loss: 0.004758
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0026
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# Train Epoch: 10 [30400/60000 (51%)]	Loss: 0.004693
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# Train Epoch: 10 [30720/60000 (51%)]	Loss: 0.004533
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# Train Epoch: 10 [31040/60000 (52%)]	Loss: 0.004753
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0027
# Train Epoch: 10 [31360/60000 (52%)]	Loss: 0.004895
# ====> Epoch: 10 Average loss: 0.0027
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# Train Epoch: 10 [31680/60000 (53%)]	Loss: 0.005130
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 0.004858
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# Train Epoch: 10 [32320/60000 (54%)]	Loss: 0.005135
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0028
# ====> Epoch: 10 Average loss: 0.0029
# Train Epoch: 10 [32640/60000 (54%)]	Loss: 0.004930
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# Train Epoch: 10 [32960/60000 (55%)]	Loss: 0.005033
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# Train Epoch: 10 [33280/60000 (55%)]	Loss: 0.005169
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# Train Epoch: 10 [33600/60000 (56%)]	Loss: 0.004566
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0029
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# Train Epoch: 10 [33920/60000 (57%)]	Loss: 0.004583
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# Train Epoch: 10 [34240/60000 (57%)]	Loss: 0.004941
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# Train Epoch: 10 [34560/60000 (58%)]	Loss: 0.005035
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# Train Epoch: 10 [34880/60000 (58%)]	Loss: 0.004189
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0030
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# Train Epoch: 10 [35200/60000 (59%)]	Loss: 0.004987
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# Train Epoch: 10 [35520/60000 (59%)]	Loss: 0.004538
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# Train Epoch: 10 [35840/60000 (60%)]	Loss: 0.004564
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# Train Epoch: 10 [36160/60000 (60%)]	Loss: 0.004652
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0031
# ====> Epoch: 10 Average loss: 0.0032
# ====> Epoch: 10 Average loss: 0.0032
# ====> Epoch: 10 Average loss: 0.0032
# Train Epoch: 10 [36480/60000 (61%)]	Loss: 0.005062
# ...
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.004757
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# Train Epoch: 10 [48320/60000 (81%)]	Loss: 0.004794
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# Train Epoch: 10 [48640/60000 (81%)]	Loss: 0.004581
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# Train Epoch: 10 [48960/60000 (82%)]	Loss: 0.005115
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0041
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# Train Epoch: 10 [49280/60000 (82%)]	Loss: 0.004523
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# Train Epoch: 10 [49600/60000 (83%)]	Loss: 0.004680
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# Train Epoch: 10 [49920/60000 (83%)]	Loss: 0.004597
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# Train Epoch: 10 [50240/60000 (84%)]	Loss: 0.004864
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0042
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# Train Epoch: 10 [50560/60000 (84%)]	Loss: 0.004848
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# Train Epoch: 10 [50880/60000 (85%)]	Loss: 0.004728
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.004714
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# Train Epoch: 10 [51520/60000 (86%)]	Loss: 0.004645
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0043
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# Train Epoch: 10 [51840/60000 (86%)]	Loss: 0.004229
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# Train Epoch: 10 [52160/60000 (87%)]	Loss: 0.004553
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# Train Epoch: 10 [52480/60000 (87%)]	Loss: 0.004718
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# Train Epoch: 10 [52800/60000 (88%)]	Loss: 0.004492
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0044
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# Train Epoch: 10 [53120/60000 (89%)]	Loss: 0.004596
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# Train Epoch: 10 [53440/60000 (89%)]	Loss: 0.004543
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# Train Epoch: 10 [53760/60000 (90%)]	Loss: 0.004716
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# Train Epoch: 10 [54080/60000 (90%)]	Loss: 0.004553
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0045
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# Train Epoch: 10 [54400/60000 (91%)]	Loss: 0.004457
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# Train Epoch: 10 [54720/60000 (91%)]	Loss: 0.004748
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# Train Epoch: 10 [55040/60000 (92%)]	Loss: 0.005070
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# Train Epoch: 10 [55360/60000 (92%)]	Loss: 0.004723
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0046
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# Train Epoch: 10 [55680/60000 (93%)]	Loss: 0.004677
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# Train Epoch: 10 [56000/60000 (93%)]	Loss: 0.004497
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# Train Epoch: 10 [56320/60000 (94%)]	Loss: 0.004487
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# Train Epoch: 10 [56640/60000 (94%)]	Loss: 0.004427
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0047
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# Train Epoch: 10 [56960/60000 (95%)]	Loss: 0.004465
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# Train Epoch: 10 [57280/60000 (95%)]	Loss: 0.004753
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.004566
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# Train Epoch: 10 [57920/60000 (97%)]	Loss: 0.004488
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0048
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# Train Epoch: 10 [58240/60000 (97%)]	Loss: 0.004714
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# Train Epoch: 10 [58560/60000 (98%)]	Loss: 0.004362
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# Train Epoch: 10 [58880/60000 (98%)]	Loss: 0.004301
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# Train Epoch: 10 [59200/60000 (99%)]	Loss: 0.004268
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# ====> Epoch: 10 Average loss: 0.0049
# Train Epoch: 10 [59520/60000 (99%)]	Loss: 0.004671
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# Train Epoch: 10 [59840/60000 (100%)]	Loss: 0.004612
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050
# ====> Epoch: 10 Average loss: 0.0050

# %% [markdown]
# ## **Part 4: Visualizing the VAE output** (90 points)
#
# We will look at how well the codes produced by the VAE can be interpolated. **For this section we will only use the MNIST test set. **
#
# To create an interpolation between two images A and B, we encode both these images and generate a sample code for each of them. We now consider 7 equally spaced points in between these two sample codes giving us a total of 9 points including the samples. We then decode these images to get interpolated images in between A and B.
#
# Complete the interpolation function below that takes a pair of images A and B and returns 9 images. (You are free to use any data structure you want to return these images)

# %%
import matplotlib.pyplot as plt
from torchvision import utils
import numpy as np

def create_interpolates(A, B, encoder, decoder):
    muA, logvarA = encoder.forward(A)
    zA = sample(muA, logvarA)
    recon_a = decoder.forward(zA)
    muB, logvarB = encoder.forward(B)
    zB = sample(muB, logvarB)
    recon_b = decoder.forward(zB)
    result = [recon_a.detach().cpu().reshape([28,28])]
    muDiff = (muB-muA)/7
    muTemp = muA
    for i in range(7):
        muTemp += muDiff
        zTemp = sample(muTemp, logvarA)
        result.append(decoder.forward(zTemp).detach().cpu().reshape([28,28]))
    result.append(recon_b.detach().cpu().reshape([28,28]))
    return result

# %% [markdown]
# **For 10 pairs of MNIST test images of the same digit (1 pair for "0", 1 pair for "1", etc.), selected at random, compute the code for each image of the pair. Now compute 7 evenly spaced linear interpolates between these codes, and decode the result into images. Prepare a figure showing this interpolate. Lay out the figure so each interpolate is a row. On the left of the row is the first test image; then the interpolate closest to it; etc; to the last test image. You should have a 10 rows (1 row per digit) and 9 columns (7 interpolates + 2 selected test images) of images. (45 points)**

# %%
similar_pairs = {}
for _, (x, y) in enumerate(test_loader):
  for i in range(len(y)):
    if y[i].item() not in similar_pairs:
      similar_pairs[y[i].item()] = []
    if len(similar_pairs[y[i].item()])<2:
      similar_pairs[y[i].item()].append(x[i])
  
  done = True
  for i in range(10):
    if i not in similar_pairs or len(similar_pairs[i])<2:
      done = False
  
  if done:
    break

# similar_pairs[i] contains two images indexed at 0 and 1 that have images of the digit i

# %%
allP = []
for j in range(10):
    A, B = similar_pairs[j][0], similar_pairs[j][1]
    A = A.view(A.shape[0],-1)
    B = B.view(B.shape[0],-1)
    A = A.cuda()
    B = B.cuda()
    allP.append(create_interpolates(A, B, encoder, decoder))
        
fig = plt.figure(figsize=(10,9))
for i in range(90):
    fig.add_subplot(10,9,i+1)
    plt.imshow(allP[i//9][i%9])
fig.show()

# %% [markdown]
# **For 10 pairs of MNIST test images, selected at random, compute the code for each image of the pair. Now compute 7 evenly spaced linear interpolates between these codes, and decode the result into images. Prepare a figure showing this interpolate. Lay out the figure so each interpolate is a row. On the left of the row is the first test image; then the interpolate closest to it; etc; to the last test image. You should have a 10 rows and 9 columns of images. (45 points)**

# %%
random_pairs = {}
for _, (x, y) in enumerate(test_loader):
  # Make sure the batch size is greater than 20
  for i in range(10):
    random_pairs[i] = []
    random_pairs[i].append(x[2*i])
    random_pairs[i].append(x[2*i+1])
  break
# random_pairs[i] contains two images indexed at 0 and 1 that are chosen at random
allP = []
for j in range(10):
    A, B = random_pairs[j][0], random_pairs[j][1]
    A = A.view(A.shape[0],-1)
    B = B.view(B.shape[0],-1)
    A = A.cuda()
    B = B.cuda()
    allP.append(create_interpolates(A, B, encoder, decoder))
        
fig = plt.figure(figsize=(10,9))
for i in range(90):
    fig.add_subplot(10,9,i+1)
    plt.imshow(allP[i//9][i%9])
fig.show()
